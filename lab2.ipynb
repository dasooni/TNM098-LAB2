# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Pass TSV file into read_csv with tab separator
eye_data = pd.read_csv('./material/EyeTrack-raw.tsv', sep='\t')

x = eye_data['GazePointX(px)']
y = eye_data['GazePointY(px)']

# %%
plt.hist2d(x, y, bins=100)
plt.show()
